# %%
#NLP Gerçek Hayat Örneği Yapay Zeka Telefon Bankacılığı Proje - Makine Öğrenmesi
#NLP Real Life Example Artificial Intelligence Phone Banking Project - Machine Learning

# %%
#https://www.kaggle.com/datasets/cagrigungor/telefon-bankacl-mobile-bank

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
pd.read_csv('banka.csv')
# Out:
#      Unnamed: 0                                              sorgu  \
# 0             0                            kredi kartımı kaybettim
# 1             1                            banka kartımı kaybettim
# 2             2                          kredi kartımı bulamıyorum
# 3             3                               kredi kartım çalındı
# 4             4                 kredi kartımın olduğunu bilmiyorum
# ..          ...                                                ...
# 138          42              havale işlemi gereken bilgiler neler
# 139          43  kredi kartıyla güvenli para transferi yapmak i...
# 140          44  para gönderme işlemi sonrasında bilgilendirme ...
# 141          45                            eft işlem süresi nedir
# 142          46  mobil cüzdan kolay para transferi yapmak istiy...
#
#             label  le
# 0       kartkayip   1
# 1       kartkayip   1
# 2       kartkayip   1
# 3       kartkayip   1
# 4       kartkayip   1
# ..            ...  ..
# ...

# %%
df=pd.read_csv('banka.csv')
df.head(3)
# Out:
#    Unnamed: 0                      sorgu      label  le
# 0           0    kredi kartımı kaybettim  kartkayip   1
# 1           1    banka kartımı kaybettim  kartkayip   1
# 2           2  kredi kartımı bulamıyorum  kartkayip   1

# %%
df=df[["sorgu","label"]]
#küçük harfe çevrilmesi lazım,
#noktalama işaretlerini kaldırmmız lazım,
#stop words kaldırmamız lazım
df.head(3)
# Out:
#                        sorgu      label
# 0    kredi kartımı kaybettim  kartkayip
# 1    banka kartımı kaybettim  kartkayip
# 2  kredi kartımı bulamıyorum  kartkayip

# %%
#türkçe stop words kelimeler
stopwords=['fakat','lakin','ancak','acaba', 'ama', 'aslında', 'az', 'bazı', 'belki',
 'biri', 'birkaç', 'birşey', 'biz', 'bu', 'çok', 'çünkü', 'da', 'daha', 'de',
 'defa', 'diye', 'eğer', 'en', 'gibi', 'hem', 'hep', 'hepsi', 'her', 'hiç',
 'için', 'ile', 'ise', 'kez', 'ki', 'kim', 'mı', 'mu', 'mü', 'nasıl', 'ne',
 'neden', 'nerde', 'nerede', 'nereye', 'niçin', 'niye', 'o', 'sanki', 'şey',
 'siz', 'şu', 'tüm', 've', 'veya', 'ya', 'yani']

# %%
mesaj=input("Yapmak İstediniz İşlemi Giriniz.")

mesajdf=pd.DataFrame({"sorgu":mesaj,"label":0},index=[42])

df=pd.concat([df,mesajdf],ignore_index=True)



for word in stopwords:
    word=" "+word+" "
    df['sorgu']=df['sorgu'].str.replace(word," ")

cv=CountVectorizer(max_features=50)


x=cv.fit_transform(df['sorgu']).toarray()
y=df['label']


tahmin=x[-1].copy()

x=x[0:-1]
y=y[0:-1]

x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=21,train_size=0.7)

rf=RandomForestClassifier()
model=rf.fit(x_train,y_train)
skor=model.score(x_test,y_test)

sonuc=model.predict([tahmin])

print("Sonuc:",sonuc,"Skor:",skor)
# Out:
# Yapmak İstediniz İşlemi Giriniz.para göndermek istiyorum
# Sonuc: ['paragonderme'] Skor: 1.0

# %%
# LLM -> chargpt , bard , siri
